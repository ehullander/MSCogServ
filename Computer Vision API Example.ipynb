# %% [markdown]
# # Project Oxford: Computer Vision API example

# %% [markdown]
# ### This Jupyter notebook shows you how to get started with the Project Oxford <b>Computer Vision API</b> in Python, and how to visualize your results.

# %% [markdown]
# To use this notebook, you will need to get keys to <b>Computer Vision API</b>. Visit <a href="http://www.projectoxford.ai/vision">www.projectoxford.ai/vision</a>, and then the “Try for free” button. On the “Sign in” page, use your Microsoft account to sign in and you will be able to subscribe to Computer Vision API and get free keys (Code of Conduct and TOS). After completing the sign-up process, paste your key into the variables section below. (Either the primary or the secondary key works.)

# %%
import matplotlib.pyplot as plt
import numpy as np
import requests
import cv2
import pandas as pd
# %matplotlib inline 
# Display images within Jupyter

# %%
cd MS\ Cognitive\ Services\ Demo
# Out:
# [Errno 2] No such file or directory: 'MS Cognitive Services Demo'
# /Users/erichullander/Dropbox (Neal Analytics)/MS Cognitive Services Demo

# %%
from MSCogServ3 import CogServ, images
from keys import CVkey, Emotionkey, Facekey
MyImage = CogServ()
ImageUrls = images()

# %% [markdown]
# # Analyze an Image from the Web

# %%
urlImage = ImageUrls.urls[-1]
plt.figure(figsize = (8,10))
plt.imshow(MyImage.get_Source(urlImage, True))
plt.title(urlImage)

# %%
MyImage.get_OCR(CVkey)

# %%
print MyImage.OCR.words
# Out:
# русский гусеница змея ммо сорока динозавр игуана тукан снегирь попугаи утка Б белка ёж киви филин ээму• юю оробей журавль лягушка рыба Р хорёк съем ящерица WAGEIO: 145433797 wmushutterstock.ccm

# %%
MyImage = CogServ()
urlImage = ImageUrls.urls[-2]
plt.figure(figsize = (8,10))
plt.imshow(MyImage.get_Source(urlImage, True))
plt.title(urlImage)

# %%
MyImage.get_OCR(CVkey)
MyImage.get_Analyze(CVkey)

# %%
print(MyImage.OCR.words)
# Out:
# MILES COLUMBIA o Kind of Blue with Julian "Cannonball" Adderley Paul Chambers James Cobb John Coltrane Bill Evans Wynton Kelly

# %%
print MyImage.Analyze.tags
# Out:
# [u'person', u'text', u'book', u'man', u'photo', u'wearing', u'black', u'suit', u'standing', u'white']

# %%
MyImage = CogServ()
urlImage = ImageUrls.urls[0]
plt.figure(figsize = (8,10))
plt.imshow(MyImage.get_Source(urlImage, True))
plt.title(urlImage)

# %%
MyImage.get_Face(Facekey)
MyImage.get_Emotion(Emotionkey)
MyImage.get_Analyze(CVkey)

# %%
MyImage.Analyze.faces()

# %%
emotion_df = pd.DataFrame.from_dict(MyImage.Emotion.result[0])
pd.DataFrame(emotion_df[np.isfinite(emotion_df['scores'])]['scores']).sort_values('scores', ascending = False)
# Out:
#                  scores
# happiness  9.999698e-01
# anger      2.687657e-05
# sadness    1.233088e-06
# neutral    1.097957e-06
# disgust    5.121582e-07
# contempt   2.626547e-07
# surprise   2.002873e-07
# fear       5.313648e-08

# %%
MyImage.Face.result
# Out:
# [{u'faceId': u'252117e0-281c-40d1-9d5e-2e1b277ab6d0',
#   u'faceLandmarks': {u'eyeLeftBottom': {u'x': 323.2, u'y': 331.5},
#    u'eyeLeftInner': {u'x': 339.8, u'y': 329.0},
#    u'eyeLeftOuter': {u'x': 304.1, u'y': 328.1},
#    u'eyeLeftTop': {u'x': 323.3, u'y': 321.0},
#    u'eyeRightBottom': {u'x': 448.8, u'y': 333.1},
#    u'eyeRightInner': {u'x': 428.5, u'y': 330.7},
#    u'eyeRightOuter': {u'x': 467.7, u'y': 329.2},
#    u'eyeRightTop': {u'x': 447.9, u'y': 322.2},
#    u'eyebrowLeftInner': {u'x': 353.7, u'y': 304.4},
#    u'eyebrowLeftOuter': {u'x': 277.5, u'y': 308.9},
#    u'eyebrowRightInner': {u'x': 413.5, u'y': 303.5},
#    u'eyebrowRightOuter': {u'x': 495.3, u'y': 305.7},
#    u'mouthLeft': {u'x': 314.0, u'y': 420.0},
#    u'mouthRight': {u'x': 455.2, u'y': 426.0},
#    u'noseLeftAlarOutTip': {u'x': 340.2, u'y': 377.9},
#    u'noseLeftAlarTop': {u'x': 359.5, u'y': 356.3},
#    u'noseRightAlarOutTip': {u'x': 430.6, u'y': 379.7},
#    u'noseRightAlarTop': {u'x': 412.9, u'y': 357.5},
#    u'noseRootLeft': {u'x': 367.7, u'y': 331.8},
#    u'noseRootRight': {u'x': 403.6, u'y': 333.4},
#    u'noseTip': {u'x': 383.3, u'y': 384.0},
#    u'pupilLeft': {u'x': 318.9, u'y': 325.7},
#    u'pupilRight': {u'x': 445.3, u'y': 326.9},
#    u'underLipBottom': {u'x': 383.7, u'y': 467.9},
#    u'underLipTop': {u'x': 382.9, u'y': 454.8},
#    u'upperLipBottom': {u'x': 382.2, u'y': 424.2},
#    u'upperLipTop': {u'x': 381.9, u'y': 415.6}},
#   u'faceRectangle': {u'height': 253,
#    u'left': 257,
#    u'top': 247,
#    u'width': 253}},
#  {u'faceId': u'dae8bd12-b452-46a6-8101-e4cc6bade47c',
#   u'faceLandmarks': {u'eyeLeftBottom': {u'x': 64.0, u'y': 509.2},
#    u'eyeLeftInner': {u'x': 68.9, u'y': 507.7},
#    u'eyeLeftOuter': {u'x': 59.8, u'y': 506.9},
#    u'eyeLeftTop': {u'x': 64.1, u'y': 505.9},
#    u'eyeRightBottom': {u'x': 87.0, u'y': 510.3},
#    u'eyeRightInner': {u'x': 83.8, u'y': 508.6},
#    u'eyeRightOuter': {u'x': 91.0, u'y': 508.1},
#    u'eyeRightTop': {u'x': 86.9, u'y': 507.4},
#    u'eyebrowLeftInner': {u'x': 73.9, u'y': 504.3},
#    u'eyebrowLeftOuter': {u'x': 54.3, u'y': 500.2},
#    u'eyebrowRightInner': {u'x': 84.4, u'y': 505.0},
#    u'eyebrowRightOuter': {u'x': 95.5, u'y': 502.6},
#    u'mouthLeft': {u'x': 63.6, u'y': 530.1},
#    u'mouthRight': {u'x': 79.7, u'y': 530.2},
#    u'noseLeftAlarOutTip': {u'x': 69.5, u'y': 522.0},
#    u'noseLeftAlarTop': {u'x': 72.0, u'y': 517.3},
#    u'noseRightAlarOutTip': {u'x': 82.3, u'y': 520.9},
#    u'noseRightAlarTop': {u'x': 80.9, u'y': 517.4},
#    u'noseRootLeft': {u'x': 75.7, u'y': 508.7},
#    u'noseRootRight': {u'x': 81.2, u'y': 509.3},
#    u'noseTip': {u'x': 78.4, u'y': 521.9},
#    u'pupilLeft': {u'x': 64.5, u'y': 507.7},
#    u'pupilRight': {u'x': 87.3, u'y': 508.8},
#    u'underLipBottom': {u'x': 74.5, u'y': 534.9},
#    u'underLipTop': {u'x': 74.7, u'y': 532.0},
#    u'upperLipBottom': {u'x': 74.4, u'y': 531.3},
#    u'upperLipTop': {u'x': 74.2, u'y': 529.4}},
#   u'faceRectangle': {u'height': 47, u'left': 51, u'top': 496, u'width': 47}}]

# %%
print MyImage.Analyze.tags
# Out:
# [u'person', u'indoor', u'man', u'photo', u'smiling', u'posing', u'table', u'white', u'front', u'black', u'camera', u'sitting', u'food', u'holding', u'eating', u'standing', u'large', u'restaurant', u'shirt', u'young', u'wearing', u'old', u'kitchen']

# %%
MyImage.Analyze.categories
# Out:
# (u'people_portrait', 0.76953125)

# %%
MyImage.Analyze.caption
# Out:
# (u'a man that is posing for a photo', 0.49720867774696703)

# %%
plt.figure(figsize = (8,10))
plt.imshow(MyImage.get_Source('Eric.jpg', False))
plt.title(urlImage)

# %%
MyImage.Face_api(Facekey)
MyImage.Emotion_api(Emotionkey)
MyImage.Analyze_api(CVkey)

# %%
MyImage.Analyze.caption
# Out:
# (u'a man wearing a neck tie', 0.26423504320225877)

# %%
MyImage.Emotion.result
# Out:
# [{u'faceRectangle': {u'height': 939, u'left': 694, u'top': 867, u'width': 939},
#   u'scores': {u'anger': 1.07337e-07,
#    u'contempt': 3.83527731e-05,
#    u'disgust': 8.257995e-07,
#    u'fear': 9.708776e-10,
#    u'happiness': 0.999862969,
#    u'neutral': 9.229775e-05,
#    u'sadness': 5.41486042e-06,
#    u'surprise': 2.308336e-08}}]
